# %%
def linecount(filename):
    count = 0
    for line in open(filename):
        count += 1
    return count

if __name__ == '__main__':
    print(linecount('wc.py'))
# Out:
# 9

# %%
import wc
wc
# Out:
# <module 'wc' from 'C:\\Users\\lifei\\wc.py'>

# %%
wc.linecount('Untitled.ipynb')
# Out:
# 66
